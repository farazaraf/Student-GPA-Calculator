# %% [markdown]
# <a href="https://colab.research.google.com/github/farazaraf/Student-GPA-Calculator/blob/main/Exploratory_data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Engineering Management Project**
# Group:
#
# Faraz Ahmad Qureshi - 200901045
#
# Hamza Humayune - 200901085

# %% [markdown]
# ## Let us find the dataset and perform Exploratory Data Analysis on it

# %% [markdown]
# ## Introduction

# %% [markdown]
# **What is Exploratory Data Analysis ?**
#
# Exploratory Data Analysis or (EDA) is understanding the data sets by summarizing their main characteristics often plotting them visually. This step is very important especially when we arrive at modeling the data in order to apply Machine learning. Plotting in EDA consists of Histograms, Box plot, Scatter plot and many more. It often takes much time to explore the data. Through the process of EDA, we can ask to define the problem statement or definition on our data set which is very important.

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Importing the required libraries for EDA

# %% [markdown]
# Below are the libraries that are used in order to perform EDA (Exploratory data analysis)

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Loading the data into the data frame.

# %% [markdown]
# Loading the data into the pandas data frame is certainly one of the most important steps in EDA, as we can see that the value from the data set is comma-separated. So all we have to do is to just read the CSV into a data frame and pandas data frame does the job for us.

# %% [markdown]
# To get or load the dataset into the notebook, in Google Colab at the left-hand side of the notebook, you will find a > (greater than symbol). When you click that you will find a tab with three options, you just have to select Files. Then you can easily upload your file with the help of the Upload option. One thing to remember in this step is that uploaded files will get deleted when this runtime is recycled. This is how to get the data set into the notebook.

# %%
df = pd.read_csv("dataset.csv")
# To display the top 5 rows
df.head(5)
# Out:
#    ID No.  Program of Study Gender Nationality Place of Birth  \
# 0       1  Computer Science   Male   Pakistani         Punjab
# 1       2  Computer Science   Male   Pakistani         Punjab
# 2       3  Computer Science   Male   Pakistani         Punjab
# 3       4  Computer Science   Male   Pakistani         Punjab
# 4       5  Computer Science   Male   Pakistani            KPK
#
#   Father's Education Mother's Education    Parental Income  \
# 0                 MS        PhD/ Doctor   Between 50K~1Lac
# 1                 BS        PhD/ Doctor  Between 1Lac~2Lac
# 2                 MS        PhD/ Doctor  Between 2Lac~3Lac
# 3                 MS       Intermediate  Between 1Lac~2Lac
# 4                 BS       Intermediate   Between 50K~1Lac
#
#   Number of immediate family members  \
# 0                                  5
# 1                                  5
# 2                                  6
# 3                                  6
# 4                                  5
#
# ...

# %%
df.tail(5)                        # To display the botton 5 rows

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Checking the types of data

# %% [markdown]
# Here we check for the datatypes

# %%
df.dtypes
# Out:
# ID No.                                                                                     int64
# Program of Study                                                                          object
# Gender                                                                                    object
# Nationality                                                                               object
# Place of Birth                                                                            object
#                                                                                            ...
# I often come across health issues that effect my academic performance.                    object
# My preferable mode of study is:                                                           object
# My preferable time of study is:                                                           object
# My overall mobile usage (daily) for non-academic purpose is limited to:                   object
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Dropping irrelevant columns

# %% [markdown]
# This step is certainly needed in every EDA because sometimes there would be many columns that we never use in such cases dropping is the only solution.

# %%
df = df.drop(['Program of Study', 'Nationality', 'Basic Education Stream', 'Intermediate Stream', 'I understand the lecture more clearly if delivered on:', 'I understand the lecture more clearly if delivered in:', 'I understand the lecture more clearly if delivered by:', 'Identify any other variable that has negatively impacted on your academic performance.'], axis=1)
df.head(5)
# Out:
#    ID No. Gender Place of Birth Father's Education Mother's Education  \
# 0       1   Male         Punjab                 MS        PhD/ Doctor
# 1       2   Male         Punjab                 BS        PhD/ Doctor
# 2       3   Male         Punjab                 MS        PhD/ Doctor
# 3       4   Male         Punjab                 MS       Intermediate
# 4       5   Male            KPK                 BS       Intermediate
#
#      Parental Income Number of immediate family members  \
# 0   Between 50K~1Lac                                  5
# 1  Between 1Lac~2Lac                                  5
# 2  Between 2Lac~3Lac                                  6
# 3  Between 1Lac~2Lac                                  6
# 4   Between 50K~1Lac                                  5
#
#   Any close family member with the same profession available for guidance  \
# 0                                                YES
# 1                                                 NO
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Renaming the columns

# %% [markdown]
# In this instance, some column names can be simplified, so we just tweaked their column names. This is a good approach it improves the readability of the data set.

# %%
df = df.rename(columns={"Father's Education":"FathersEducation", "Mother's Education":"MothersEducation"})
df.head(5)

# %% [markdown]
# ---

# %% [markdown]
# ## 6. Dropping the duplicate rows

# %% [markdown]
# **This is often a handy thing to do inorder to avoid problems with the dataset**

# %%
df.shape
# Out:
# (73, 68)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 68)

# %% [markdown]
# Now let us remove the duplicate data because it's ok to remove them.

# %%
df.count()
# Out:
# ID No.                                                                             73
# Gender                                                                             73
# Place of Birth                                                                     73
# Father's Education                                                                 73
# Mother's Education                                                                 73
#                                                                                    ..
# My classes schedule is usually very tight that hinders the process of learning.    73
# I often come across health issues that effect my academic performance.             73
# My preferable mode of study is:                                                    73
# My preferable time of study is:                                                    73
# My overall mobile usage (daily) for non-academic purpose is limited to:            73
# Length: 68, dtype: int64

# %% [markdown]
# ###**Encoding the data that we can use to perform EDA**

# %%
from sklearn.preprocessing import OrdinalEncoder
# Create the data
# Instantiate the encoder
df[["FathersEducation"]]= OrdinalEncoder(categories=[['Below Matric','Matric', 'Intermediate', 'BS', 'MS','PhD/ Doctor']]).fit_transform(df[["FathersEducation"]])

# Fit and transform the data
#df[["FathersEducation"]] # Print the encoded data
df.head(5)
# Out:
#    ID No. Gender Place of Birth  FathersEducation MothersEducation  \
# 0       1   Male         Punjab               4.0      PhD/ Doctor
# 1       2   Male         Punjab               3.0      PhD/ Doctor
# 2       3   Male         Punjab               4.0      PhD/ Doctor
# 3       4   Male         Punjab               4.0     Intermediate
# 4       5   Male            KPK               3.0     Intermediate
#
#      Parental Income Number of immediate family members  \
# 0   Between 50K~1Lac                                  5
# 1  Between 1Lac~2Lac                                  5
# 2  Between 2Lac~3Lac                                  6
# 3  Between 1Lac~2Lac                                  6
# 4   Between 50K~1Lac                                  5
#
#   Any close family member with the same profession available for guidance  \
# 0                                                YES
# 1                                                 NO
# ...

# %%
df[["MothersEducation"]]= OrdinalEncoder(categories=[['Below Matric','Matric', 'Intermediate', 'BS', 'MS','PhD/ Doctor']]).fit_transform(df[["MothersEducation"]])

# Fit and transform the data
#df[["MothersEducation"]] # Print the encoded data
df.head(5)
# Out:
#    ID No. Gender Place of Birth  FathersEducation  MothersEducation  \
# 0       1   Male         Punjab               4.0               5.0
# 1       2   Male         Punjab               3.0               5.0
# 2       3   Male         Punjab               4.0               5.0
# 3       4   Male         Punjab               4.0               2.0
# 4       5   Male            KPK               3.0               2.0
#
#      Parental Income Number of immediate family members  \
# 0   Between 50K~1Lac                                  5
# 1  Between 1Lac~2Lac                                  5
# 2  Between 2Lac~3Lac                                  6
# 3  Between 1Lac~2Lac                                  6
# 4   Between 50K~1Lac                                  5
#
#   Any close family member with the same profession available for guidance  \
# 0                                                YES
# 1                                                 NO
# ...

# %%
df[["Parental Income"]]= OrdinalEncoder(categories=[['Below 30K','Between 30K~50K','Between 50K~1Lac', 'Between 1Lac~2Lac', 'Between 2Lac~3Lac', 'Above 3Lac']]).fit_transform(df[["Parental Income"]])
# Fit and transform the data
#df[["Parental Income"]] # Print the encoded data
df.head(5)
# Out:
#    ID No. Gender Place of Birth  FathersEducation  MothersEducation  \
# 0       1   Male         Punjab               4.0               5.0
# 1       2   Male         Punjab               3.0               5.0
# 2       3   Male         Punjab               4.0               5.0
# 3       4   Male         Punjab               4.0               2.0
# 4       5   Male            KPK               3.0               2.0
#
#    Parental Income Number of immediate family members  \
# 0              2.0                                  5
# 1              3.0                                  5
# 2              4.0                                  6
# 3              3.0                                  6
# 4              2.0                                  5
#
#   Any close family member with the same profession available for guidance  \
# 0                                                YES
# 1                                                 NO
# ...

# %%
df2 = df.iloc[:,23:67]
#df2 = df2.drop(columns=['What is your residence place?','My preferable mode of study is:','My preferable time of study is:'])
df2.drop(columns=['What is your residence place?','My preferable mode of study is:','My preferable time of study is:'],inplace=True)
df2.head(3)
# Out:
#   TVFs often reschedule classes that negatively impacts my performance.  \
# 0                                              Agree
# 1                                  Strongly disagree
# 2                                           Disagree
#
#   TVFs are very difficult to access after class timings and hence I am unable to clarify my concepts.  \
# 0                                              Agree
# 1                                            Neutral
# 2                                     Strongly agree
#
#   TVFs do not provide assessment results timely so I remain unaware of my standing in class.  \
# 0                                            Neutral
# 1                                            Neutral
# 2                                     Strongly agree
#
#   TVFs are not aware of the university's curriculum and other requirements.  \
# 0                                            Neutral
# 1                                  Strongly disagree
# ...

# %%
df2.replace("Strongly agree", "Strongly Agree",inplace=True)
df2.replace("Strongly disagree", "Strongly Disagree",inplace=True)
df2.head(3)
#df2.replace("Strongly agree", "Strongly Agree", inplace=True)
#df2.replace("Strongly disagree", "Strongly Disagree", inplace=True)
# Out:
#   TVFs often reschedule classes that negatively impacts my performance.  \
# 0                                              Agree
# 1                                  Strongly Disagree
# 2                                           Disagree
#
#   TVFs are very difficult to access after class timings and hence I am unable to clarify my concepts.  \
# 0                                              Agree
# 1                                            Neutral
# 2                                     Strongly Agree
#
#   TVFs do not provide assessment results timely so I remain unaware of my standing in class.  \
# 0                                            Neutral
# 1                                            Neutral
# 2                                     Strongly Agree
#
#   TVFs are not aware of the university's curriculum and other requirements.  \
# 0                                            Neutral
# 1                                  Strongly Disagree
# ...

# %% [markdown]
# Encoding Ordinal / Categorical Data

# %%
cat=['Strongly Disagree','Disagree', 'Neutral', 'Agree', 'Strongly Agree']
encoded_df = pd.DataFrame()
encoder = OrdinalEncoder(categories=[cat])
#for column in df2.columns:
for column in df2.columns:
    # Ensure that the column contains object dtype (categorical)
    if df2[column].dtype == 'O':
        # Fit and transform the data for the current column
        encoded_column = encoder.fit_transform(df2[[column]])
        # Add the encoded column to the new DataFrame
        encoded_df[column] = encoded_column.flatten()
    else:
        # If the column is not categorical, keep it as is
        encoded_df[column] = df2[column]

# %%
encoded_df.tail(10)
# Out:
#     TVFs often reschedule classes that negatively impacts my performance.  \
# 63                                                0.0
# 64                                                3.0
# 65                                                4.0
# 66                                                2.0
# 67                                                2.0
# 68                                                2.0
# 69                                                2.0
# 70                                                1.0
# 71                                                2.0
# 72                                                3.0
#
#     TVFs are very difficult to access after class timings and hence I am unable to clarify my concepts.  \
# 63                                                3.0
# 64                                                1.0
# 65                                                3.0
# 66                                                2.0
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 7. Plot different features against one another

# %% [markdown]
# ### **Boxplot**
# These Boxplot showcase the GPAs that have been achieved by students throughout the first five semesters as well as their CGPA until fifth semester.

# %%
# %matplotlib inline
semesterGPAs= df.loc[:,'SGPA in BS First semester':'CGPA in BS Fifth semester']

fig, axes = plt.subplots(2, 3, figsize=(8, 6))

# Flatten the axes for easy indexing
axes = axes.flatten()

# Plot box plots for each semester
for i, semester in enumerate(semesterGPAs):
    sns.boxplot(x=df[semester], ax=axes[i], color='skyblue')
    axes[i].set_title(f'{semester}')
    axes[i].set_xlabel('GPA')
    axes[i].grid(True)

# Remove empty subplots if any
for j in range(len(semesterGPAs), len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
questions = encoded_df.columns.values  # Add all question column names

# Define the number of rows and columns for subplots
rows = 7  # Adjust based on the number of questions and your preference
cols = 6  # Adjust based on the number of questions and your preference

# Create subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, 20))

# Flatten the 2D array of subplots
axes = axes.flatten()

# Plot bar charts for each question
for i, question in enumerate(questions):
    plt.sca(axes[i])
    encoded_df[question].value_counts().sort_index().plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title(f'Question {i+1}')
    plt.xlabel('Responses')
    plt.ylabel('Frequency')
    plt.grid(axis='y')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ### **Analysis EDA**

# %%
gender_counts = df['Gender'].value_counts()

# Create a pie chart using seaborn
plt.figure(figsize=(4, 4))
sns.set(style='whitegrid')
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightcoral'], startangle=90)
plt.title('Distribution of Male and Female Students')
plt.show()

birthplace_counts = df['Place of Birth'].value_counts()

# Create a bar chart
plt.figure(figsize=(6, 4))
birthplace_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of Place of Birth')
plt.xlabel('Place of Birth')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(axis='y')
plt.show()

# %%
data_cleaned = df.dropna(subset=['SGPA in BS First semester', 'CGPA in BS Fifth semester'])
data_cleaned = data_cleaned.copy()
data_cleaned['SGPA in BS Fifth semester'] = pd.to_numeric(data_cleaned['SGPA in BS Fifth semester'], errors='coerce')
data_cleaned['CGPA in BS Fifth semester'] = pd.to_numeric(data_cleaned['CGPA in BS Fifth semester'], errors='coerce')

correlative_features = ['Gender','I often come across health issues that effect my academic performance.','Place of Birth']
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(16, 14))

for i, feature in enumerate(correlative_features):
    sns.countplot(data=data_cleaned, x=feature, ax=axes[i, 0])
    axes[i, 0].set_title(f'Distribution of {feature}')
    axes[i, 0].set_xlabel(feature)
    axes[i, 0].set_ylabel('Count')

    sns.boxplot(data=data_cleaned, x=feature, y='CGPA in BS Fifth semester', ax=axes[i, 1])
    axes[i, 1].set_title(f'Relationship between {feature} and CGPA')
    axes[i, 1].set_xlabel(feature)
    axes[i, 1].set_ylabel('CGPA in BS Fifth semester')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##**Model Training**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, explained_variance_score
from sklearn.model_selection import train_test_split

from joblib import dump

# %%
categorical_columns = data_cleaned.select_dtypes(include=['object']).columns
data_encoded = pd.get_dummies(data_cleaned, columns=categorical_columns, drop_first=True)

X = data_encoded.drop(columns=['SGPA in BS Fifth semester', 'CGPA in BS Fifth semester'])
y_cgpa = data_encoded['CGPA in BS Fifth semester']

X_train_cgpa, X_test_cgpa, y_train_cgpa, y_test_cgpa = train_test_split(X, y_cgpa, test_size=0.30, random_state=42)

rf_cgpa = RandomForestRegressor(n_estimators=100, random_state=42)
rf_cgpa.fit(X_train_cgpa, y_train_cgpa)
# Out:
# RandomForestRegressor(random_state=42)

# %%
feature_importances_cgpa = rf_cgpa.feature_importances_
feature_names = X.columns
features_cgpa_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances_cgpa})
print()
important_features_cgpa = features_cgpa_df.sort_values(by='Importance', ascending=False)
# Out:
# [2.18183978e-02 1.35564657e-03 1.17969444e-03 2.96555968e-03
#  1.75841535e-03 4.14709825e-03 3.68509462e-02 8.05913155e-02
#  6.90525776e-01 9.21464282e-02 1.44814888e-04 1.91686789e-03
#  0.00000000e+00 6.29762770e-05 2.57506086e-04 2.24068054e-04
#  5.06174244e-05 2.30753748e-04 4.47147908e-04 3.80651329e-04
#  2.46466449e-04 7.60726652e-04 7.22948597e-03 3.53989632e-07
#  7.80606752e-04 3.95135482e-04 3.75379581e-05 2.95498553e-04
#  6.97729054e-06 1.82037897e-03 0.00000000e+00 2.49310042e-03
#  5.49458570e-05 2.24340856e-05 4.46709693e-04 4.76393924e-05
#  8.56971238e-04 1.81675756e-04 6.15378614e-04 1.46130053e-04
#  3.26593883e-05 6.33558159e-05 3.61315459e-04 1.69803957e-04
#  0.00000000e+00 1.56914931e-03 3.43815109e-04 3.43372529e-06
#  4.16819278e-06 3.36434782e-04 1.34108403e-04 4.20304036e-07
#  4.24077873e-06 4.36291850e-04 2.00645917e-04 1.39166381e-04
#  0.00000000e+00 3.22320341e-05 2.70405994e-04 3.28427156e-06
# ...

# %%
models = {
    "Lasso Regressor": Lasso(random_state=42),
    "Support Vector Regressor": SVR(),
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Random Forest": RandomForestRegressor(random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42)
}

#function to train and evaluate models
def train_evaluate_models(models, X_train, y_train, X_test, y_test):
    for name, model in models.items():
        #training the model here
        model.fit(X_train, y_train)

        #predictions and evaluation
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)
        explained_var = explained_variance_score(y_test, y_pred)

        print(f"Model: {name}")
        print(f"Mean Squared Error: {mse:.4f}")
        print(f"R-squared: {r2:.4f}")
        print(f"Mean Absolute Error: {mae:.4f}")
        print(f"Explained Variance Score: {explained_var:.4f}\n")

        model_filename = f"{name}_model.joblib"
        dump(model, model_filename,compress=1)

#calling the model training function here
train_evaluate_models(models, X_train_cgpa, y_train_cgpa, X_test_cgpa, y_test_cgpa)
# Out:
# Model: Lasso Regressor
# Mean Squared Error: 0.1980
# R-squared: 0.0830
# Mean Absolute Error: 0.3756
# Explained Variance Score: 0.1706
#
# Model: Support Vector Regressor
# Mean Squared Error: 0.1902
# R-squared: 0.1189
# Mean Absolute Error: 0.3706
# Explained Variance Score: 0.2195
#
# Model: Linear Regression
# Mean Squared Error: 0.0564
# R-squared: 0.7388
# Mean Absolute Error: 0.1884
# Explained Variance Score: 0.8070
#
# Model: Decision Tree
# Mean Squared Error: 0.0347
# R-squared: 0.8393
# Mean Absolute Error: 0.1595
# Explained Variance Score: 0.8394
#
# Model: Random Forest
# Mean Squared Error: 0.0238
# R-squared: 0.8897
# Mean Absolute Error: 0.1268
# Explained Variance Score: 0.9021
#
# Model: Gradient Boosting
# Mean Squared Error: 0.0208
# R-squared: 0.9035
# Mean Absolute Error: 0.1219
# Explained Variance Score: 0.9073

# %% [markdown]
# Based on these results, the following are good contenders for our regression models:
#
# *   Random Forest:
#     *   Mean Squared Error: 0.0238
#     *   R-squared: 0.8897
#     *   Mean Absolute Error: 0.1268
#     *   Explained Variance Score: 0.9021
#
# *   Gradient Boosting
#     *   Mean Squared Error: 0.0208
#     *   R-squared: 0.9035
#     *   Mean Absolute Error: 0.1219
#     *   Explained Variance Score: 0.9073
#
# *   Decision Tree
#     *   Mean Squared Error: 0.0347
#     *   R-squared: 0.8393
#     *   Mean Absolute Error: 0.1595
#     *   Explained Variance Score: 0.8394

# %%
#Predicting using Our model:
from joblib import load

# Load the saved model
loaded_model = load('Gradient Boosting_model.joblib')

# Use the loaded model for predictions
#predictions require user to enter all details in the form before their GPA can be calculated as we use all the features for predictions.
predictions = loaded_model.predict(X_test_cgpa)
print(predictions)
# Out:
# [2.40486876 2.46275038 2.82988588 2.83249199 2.68332418 3.42854777
#  3.48970832 2.41383291 2.77923085 3.37716144 3.54380279 3.29845304
#  2.36683929 3.1032249  2.49526389 3.44775534 2.33690414 3.01792324
#  2.48190451 3.0012968  2.95022357 2.92038734]
